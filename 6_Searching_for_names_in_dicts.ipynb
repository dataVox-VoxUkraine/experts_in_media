# %% [markdown]
# ### 6. Search for filtered names in the dictionary with all names and name forms

# %%
import pandas as pd
from uk_stemmer import UkStemmer
from nltk import stem
import re
from collections import Counter
import json

# %%
stemmer_ru = stem.snowball.SnowballStemmer("russian") 
stemmer_ukr = UkStemmer()

# %% [markdown]
# ### Searching for names

# %%
entities_path = '../data/entities_may.csv'
entities = pd.read_csv(entities_path, index_col=[0])
entities.columns
# Out:
# Index(['link', 'language', 'all_ent_str', 'name_and_kw', 'kw_and_ent',
#        'names_and_kw_str', 'names_str', 'names_sets_str',
#        'one_name_per_set_str', 'string_names_sets_str', 'filt_kw_names_str',
#        'checked_with_conllu', 'checked_names_str', 'kw_names_unique_str'],
#       dtype='object')

# %%
# file with all names and name forms gathered during previous months
names_dict_path = 'joined_names_dict.csv'
names_df = pd.read_csv(names_dict_path, index_col=[0])
names_df.head()
# Out:
#                         num           stem_name  \
# name
# Володимир Зеленськ  18633.0  Володимир Зеленськ
# Макс Степан         14884.0         Макс Степан
# Денис Шмигал         9970.0        Денис Шмигал
# Дональд Трамп        5823.0       Дональд Трамп
# Джо Байден           6450.0          Джо Байден
#
#                                                          all_vars_str   id
# name
# Володимир Зеленськ  Володимир Зеленськ Перестановк§Волод Зеленск§*...  0.0
# Макс Степан         Очільник Моз Макс Степан§Здоров Макс Степан§Ма...  1.0
# Денис Шмигал        Глав Кабмін Денис Шмигал§Деніс Шмигал§Денис Шм...  2.0
# Дональд Трамп       Дональл Трамп§Дональд Трамп Сша§Дональд Трампа...  3.0
# Джо Байден          Дже Байден§: Джо Байден§Демократ Джозеф Байден...  4.0

# %%
# import ast
# entities['names_from_dict'] = entities.names_from_dict.apply(lambda x: ast.literal_eval(x) if pd.notna(x) else None)

# %%
entities['unique_kw_names'] = entities.kw_names_unique_str.str.split('§')
entities['set_names'] = entities.one_name_per_set_str.str.split('<@>')

# %%
def kw_name_str_to_list(names_and_kw_str):
    if pd.notna(names_and_kw_str):
        res = []
        for ent in names_and_kw_str.split('@+@'):
            res.append(ent.split('<+>'))
        return res
    return None

# %%
def stem_names(names_list, stemmer):
    if isinstance(names_list, list): 
        res=[]
        for name in names_list:
            stemmed_name = []
            for word in name.split():
                st = stemmer(word)
                if word[0].isupper():
                    st = st.capitalize()
                stemmed_name.append(st)
            res.append(' '.join(stemmed_name))
        return res
    return None

# %%
entities['names_from_dict'] = None
entities['found'] = False

# %%
top_names = names_df[(names_df.num>0)]
top_names.shape
# Out:
# (10874, 4)

# %%
def find_names_in_dict(stem_names, found_names, found_flag):
    if isinstance(stem_names, list) and not found_flag:
        res = {}
        if pd.notna(found_names):
            res = found_names
        for i in range(len(stem_names)):
            if (i not in res.keys()) and (stem_names[i] in top_names.index.values):
                res[i] = stem_names[i]
        if len(res) > 0:
            return res
    return None

# %%
# %%time
part = entities.apply(lambda row: find_names_in_dict(row.set_names, row.names_from_dict, row.found), axis=1)
entities['names_from_dict'].update(part)
# Out:
# CPU times: user 1min 55s, sys: 2.47 s, total: 1min 57s
# Wall time: 2min 3s

# %%
entities['found'] = entities.apply(lambda row: 
                           True if (pd.notna(row.names_from_dict) and 
                           len(row.names_from_dict)==len(row.set_names)) else False, axis=1)

# %%
entities.found.sum()
# Out:
# 20932

# %%
not_found=[]
variants=[]

# %%
top_names = names_df[names_df.all_vars_str.notna()]
top_names.shape
# Out:
# (6780, 4)

# %%
def find_names_in_variants(found_names, names, found):
    if isinstance(names, list) and not found:
        res = {}
        if pd.notna(found_names):
            res = found_names
        for i in range(len(names)):
            nf = names[i]
            if (i not in res.keys()) and \
                    (nf not in not_found) and \
                        (nf not in variants):
                nf = re.escape(nf)
                pat = rf'§{nf}§|^{nf}§|§{nf}$|^{nf}$'
                found_part = top_names[top_names.all_vars_str.str.contains(pat, na=False)]
                if len(found_part) == 1:
                    res[i] = found_part['stem_name'].iloc[0]
                elif len(found_part) > 1:
                    variants.append(names[i])
                else:
                    not_found.append(names[i])
                    
                del pat, found_part
        if len(res) > 0:
            return res
    return None

# %%
# %%time
part = entities.apply(lambda row: find_names_in_variants(row.names_from_dict, row.set_names, row.found), axis=1)

entities['names_from_dict'].update(part)

# %%
entities[(entities.found==False)&entities.unique_kw_names.notna()].shape
# Out:
# (5949, 17)

# %%
missing = []
def count_missing(stem_names, found_names, found_flag, missing):
    if isinstance(stem_names, list) and not found_flag:
        found={}
        res = [] 
        if pd.notna(found_names):
            found = found_names
        for i in range(len(stem_names)):
            if i not in found.keys():
                res.append(stem_names[i])
        res = list(set(res))
        missing += res

# %%
entities.apply(lambda row: count_missing(row.unique_kw_names, row.names_from_dict, row.found, missing), axis=1)
# Out:
# id
# 2075213    None
# 2077435    None
# 2076296    None
# 2081964    None
# 2081965    None
#            ...
# 2072553    None
# 2072554    None
# 2072555    None
# 2072556    None
# 2072557    None
# Length: 151397, dtype: object

# %%
missing_counts = Counter(missing)
missing_counts = {k: v for k, v in sorted(missing_counts.items(), key=lambda item: item[1], reverse=True)}
missing_counts
# Out:
# {'Оос': 173,
#  'Гарр': 110,
#  'Ляшк': 94,
#  'премєр': 73,
#  'Даш': 62,
#  'Вооз': 61,
#  'Сар': 55,
#  'Юл': 53,
#  'Маск': 50,
#  'Сбу': 43,
#  'Жан': 43,
#  'Олен': 43,
#  'Байд': 42,
#  'журналист': 41,
#  'Ольг': 36,
#  'Анн': 34,
#  'чиновниц': 34,
#  'Іран': 33,
#  'Тар': 33,
#  'Наст': 32,
#  'Зірк': 32,
#  'Мар': 31,
#  'Лод': 31,
#  'Серг': 30,
#  'Р': 30,
#  'Ірин': 28,
#  'очевидц': 26,
#  'Ганц': 25,
#  'Хамас': 24,
#  'Кус': 24,
#  'Ал': 21,
#  'Мкіп': 21,
#  'Бен': 20,
#  'Діан': 20,
#  'Кив': 19,
#  'Андр': 18,
#  'Рааб': 18,
#  'Офіс': 18,
#  'Віл': 18,
#  'Слав': 18,
#  'Маш': 18,
#  'Макс': 17,
#  'Усик': 17,
#  'Білл': 17,
#  'Галявієв': 17,
#  'Дзерб': 17,
#  'епідеміолог': 17,
#  'Ян': 16,
#  'Авак': 16,
#  'очевидец': 16,
#  'А': 16,
#  'Іванга': 15,
#  'Кміс': 15,
#  'Маас': 15,
#  'Лир': 15,
#  'Юр': 15,
#  'Павл': 14,
#  'Шрі': 14,
#  'Над': 14,
#  'Баст': 13,
#  'Сант': 13,
#  'Белт': 13,
#  'Ганн': 13,
#  'Саш': 13,
#  'Ігор': 12,
#  'Псак': 12,
#  'Міш': 12,
#  'Злат': 12,
#  'чоловік': 12,
#  'Ле': 12,
#  'Олег': 12,
#  'М і К . Ми з колег із правоохоронн орган': 11,
#  'Ухан': 11,
#  'Едвард Чо': 11,
#  'Пєск': 11,
#  'Хірн': 11,
#  'українк': 11,
#  'Будк': 11,
#  'Дуд': 11,
#  'Ісус': 11,
#  'Кат': 11,
#  'Ф': 10,
#  'Сіллер': 10,
#  'Фюр': 10,
#  'Лавр': 10,
#  'Петр': 10,
#  'опозиціонерк': 10,
#  'Юрик': 10,
#  'Окер': 10,
#  'Соф': 10,
#  'Ліл': 10,
#  'Галяв': 10,
#  'Ял': 10,
#  'Арт': 10,
#  'Сан': 9,
#  'Ребр': 9,
#  'Шойг': 9,
#  'клінік': 9,
#  'Пар': 9,
#  'Енин': 9,
#  'Марі': 9,
#  'Голтіс': 9,
#  'Тін': 9,
#  'Майкл О’лір': 9,
#  'жінк': 9,
#  'фон дер': 9,
#  'Шарм': 8,
#  'Моз': 8,
#  'Обам': 8,
#  'Інформцентр': 8,
#  'режисер': 8,
#  'Галущенк': 8,
#  'Джо': 8,
#  'Чаус': 8,
#  'Фіал': 8,
#  'Ол': 8,
#  'Бог': 8,
#  'Песк': 8,
#  'Ан': 8,
#  'Раджастан': 8,
#  'Жанн': 7,
#  'Вір': 7,
#  'Газ': 7,
#  'Дур': 7,
#  'Грег': 7,
#  'Маніж': 7,
#  'Амос': 7,
#  'Марк': 7,
#  'Тан': 7,
#  'Іван': 7,
#  'Ксен': 7,
#  'Рос': 7,
#  'Лкп': 7,
#  'Шейх': 6,
#  'Асад': 6,
#  'Сіс': 6,
#  'віцепремєр': 6,
#  'Юлі': 6,
#  'Дар': 6,
#  'урядовц': 6,
#  'Кім': 6,
#  'Самір': 6,
#  'Глав': 6,
#  'віцепремєрк': 6,
#  'Заліщук': 6,
#  'La Repubblica Зеленськ': 6,
#  'Алін': 6,
#  'Арч': 6,
#  'Зайк': 6,
#  'Йорг': 6,
#  'Анон': 6,
#  'аналитик': 6,
#  'Огп': 6,
#  'етнолог': 6,
#  'Аліс': 6,
#  'Кущ': 6,
#  'Фоп': 6,
#  'Лід': 6,
#  'старост': 6,
#  'Майкл О`лір': 6,
#  'Кіз': 5,
#  'Гатт': 5,
#  'Ревів': 5,
#  'Шерр Чо': 5,
#  'Барн': 5,
#  'Адел': 5,
#  'Рах': 5,
#  'Білявськ': 5,
#  'Педр': 5,
#  'Срінівас Ра': 5,
#  'Тон': 5,
#  'В': 5,
#  'Сарм': 5,
#  'Рахім': 5,
#  'седмиц': 5,
#  'Мін': 5,
#  'Кейт': 5,
#  'Міше': 5,
#  'Еміл': 5,
#  'Джон': 5,
#  'Ліз': 5,
#  'Лукашук': 5,
#  'Лев': 5,
#  'Обс': 5,
#  'Єв': 5,
#  'музикант': 5,
#  'Мерф': 5,
#  'Джол': 5,
#  'Илон': 5,
#  'Ев': 5,
#  'Лап': 5,
#  'Хан': 5,
#  'заявител': 5,
#  'шоумен': 5,
#  'Погосян': 5,
#  'Сон': 5,
#  'Кар': 5,
#  'Кирюшин Д . А': 5,
#  'Пят': 5,
#  'Син': 5,
#  'Михайліченк': 5,
#  'Дпсу': 4,
#  'Богомолец': 4,
#  'Пекельн': 4,
#  'Лін': 4,
#  'Ілон': 4,
#  'Антипович': 4,
#  'Марзук': 4,
#  'Аб': 4,
#  'Даше': 4,
#  'Радуниц': 4,
#  'співрозмовниц': 4,
#  'Бон': 4,
#  'Наді': 4,
#  'Сакв': 4,
#  'Барб': 4,
#  'Маруан І': 4,
#  'Еліз': 4,
#  'Кишкис': 4,
#  'Іка': 4,
#  'Асм': 4,
#  'Литовськ': 4,
#  'Росс': 4,
#  'Холл': 4,
#  'Лісен': 4,
#  'Дейк': 4,
#  'Лукін': 4,
#  'Галк': 4,
#  'Геродот': 4,
#  'Інд': 4,
#  'Карл': 4,
#  'Банк': 4,
#  'санлікар': 4,
#  'Шер': 4,
#  '& Johnson': 4,
#  'Шо': 4,
#  'Анас': 4,
#  'Каллорс': 4,
#  'Мол': 4,
#  'Кет': 4,
#  'Ел': 4,
#  'Мус': 4,
#  'археолог': 4,
#  'Даміан': 4,
#  'Феоф': 4,
#  'Галявиев': 4,
#  'рэпер Баст': 4,
#  'Ван': 4,
#  'Кантор': 4,
#  'Афін': 4,
#  'Кост': 4,
#  'Рев': 4,
#  'Лес': 4,
#  'Завальнюк': 4,
#  'Сел': 4,
#  'Емір': 4,
#  'Бутзелар': 4,
#  'Седушкін': 4,
#  'Гур': 4,
#  'Ілл': 4,
#  'мільярдер': 4,
#  'американец': 4,
#  'Лаврент Ян': 4,
#  'Дональд Лу': 4,
#  'Босфор': 4,
#  'Лиз': 4,
#  'Миш': 4,
#  'Онколог': 4,
#  'Сарк': 3,
#  'Гойт': 3,
#  'Голл': 3,
#  'Шарл': 3,
#  'Мусс Аб': 3,
#  'Бурл': 3,
#  'Борйанс': 3,
#  'Кше': 3,
#  'Влад': 3,
#  'М . і К . Ми з колег із правоохоронн орган': 3,
#  'Француженк': 3,
#  'Раян': 3,
#  'Ніл': 3,
#  'Габек': 3,
#  'Косте': 3,
#  'Демур': 3,
#  'модельєр': 3,
#  'Вік': 3,
#  'Єнін': 3,
#  'Джош': 3,
#  'Едд': 3,
#  'Уаіл Іс': 3,
#  'маркіз Редінг': 3,
#  'Дук': 3,
#  'Йонг': 3,
#  'Кийк': 3,
#  'Тімченк': 3,
#  'Хо': 3,
#  'Мелинд': 3,
#  'Юніс': 3,
#  'Аленськ': 3,
#  'Карнатак': 3,
#  'Дріл': 3,
#  'Петер ван': 3,
#  'Жакарезін': 3,
#  'чиновник': 3,
#  'Мэр': 3,
#  'Широкобок': 3,
#  'Ку': 3,
#  'Волк': 3,
#  'Орл': 3,
#  'Джесік': 3,
#  'Оп': 3,
#  'Ів': 3,
#  'Денніс А': 3,
#  'Роуз': 3,
#  'Пес': 3,
#  'Шур': 3,
#  'Хамдан': 3,
#  'Говраппан': 3,
#  'Долгопол': 3,
#  'Бойк': 3,
#  'Мараньян': 3,
#  'Мзс': 3,
#  'Ньяндор': 3,
#  'Франческ Ді': 3,
#  'анонім': 3,
#  'Куюн': 3,
#  'Бріджит': 3,
#  'Монр': 3,
#  'Панд': 3,
#  'Хос': 3,
#  'Уеям': 3,
#  'Кілман': 3,
#  'Щек': 3,
#  'Хар': 3,
#  'зірк': 3,
#  'Кву': 3,
#  'Саад': 3,
#  'Хирн': 3,
#  'Сулейман Ал': 3,
#  'Кішкіс': 3,
#  'Се': 3,
#  'Мурз': 3,
#  'Небытов': 3,
#  'Костржевск': 3,
#  'лорд Дайсон': 3,
#  'Шоум': 3,
#  'Ростисла': 3,
#  'Василевск': 3,
#  'Пап': 3,
#  'Швл': 3,
#  'здоров': 3,
#  'Ме': 3,
#  'киевлянин': 3,
#  'Миха Ан': 3,
#  'М .': 3,
#  'Чуприн': 3,
#  'Силантьєв': 3,
#  'Потапченк': 3,
#  'Агн': 3,
#  'Широчин': 3,
#  'Ластівк': 3,
#  'українец': 3,
#  'Хвил': 3,
#  'Банан': 3,
#  'Кайл': 3,
#  'Нін': 3,
#  'Глоб': 3,
#  'Семидідьк': 3,
#  'журналістк': 3,
#  'Елін': 3,
#  'Сміт': 3,
#  'Інн': 3,
#  'Сеіт': 3,
#  'Вівєн Лі': 3,
#  'Таюн': 3,
#  'Бумяліс': 3,
#  'сенатор': 3,
#  'Зор': 3,
#  'Сінд': 3,
#  'Цаха': 3,
#  'Плуд': 3,
#  'Наом': 3,
#  'Хом': 3,
#  'Лют': 3,
#  'Енн': 3,
#  'Юл Л': 3,
#  'Беб': 3,
#  'Гунп': 3,
#  'Богдан Го': 3,
#  'школяр': 3,
#  'Таш': 3,
#  'Федерик Iі': 3,
#  'Скида': 3,
#  'Бурб': 3,
#  'Вгород': 3,
#  'психолог': 3,
#  'Вячесла .': 3,
#  'Поп': 3,
#  'Зо': 3,
#  'Арсен "': 3,
#  'Букмекер': 3,
#  'Светла подчеркнул': 3,
#  'Карп': 3,
#  'Метр': 3,
#  'Арум': 3,
#  '& celebrity': 3,
#  'Солістк': 3,
#  'Щигол': 2,
#  'Поуелс': 2,
#  'Миронюк': 2,
#  'Прес': 2,
#  'Чергинц': 2,
#  'Руасс': 2,
#  'Белав "': 2,
#  'Возн': 2,
#  'Біл': 2,
#  'Ю . Ю': 2,
#  'Моравецьк': 2,
#  'Лукяненк': 2,
#  'Дзюб': 2,
#  'Шавуот': 2,
#  'Березосік': 2,
#  'Бал': 2,
#  'Сент': 2,
#  'Флавіан': 2,
#  'кубинец': 2,
#  'Бархум': 2,
#  'Вайт': 2,
#  'Євтух': 2,
#  'Стейнарсдоттір': 2,
#  'співрозмовник': 2,
#  'Богусл "': 2,
#  'Костржевськ': 2,
#  'Квебек': 2,
#  'Хасн': 2,
#  'Рбк': 2,
#  'Севід': 2,
#  'парламентар': 2,
#  'Рбу': 2,
#  'Сапег': 2,
#  'Мгз': 2,
#  'Карлос Iii': 2,
#  'Нбу': 2,
#  'Пол': 2,
#  'Вонг': 2,
#  'Моор': 2,
#  'Бесс': 2,
#  'Джофф': 2,
#  'Момбец': 2,
#  'Барк': 2,
#  'Сервіс Jooble': 2,
#  'Бессарабов': 2,
#  'Садикин': 2,
#  'Петр Ав': 2,
#  'Раб': 2,
#  'Стеф': 2,
#  'Дім': 2,
#  'Контрразведк': 2,
#  'Новин Н': 2,
#  'Е': 2,
#  'Пропагандист': 2,
#  'Чукуньєр': 2,
#  'Клім': 2,
#  'Нікандр': 2,
#  'Міл': 2,
#  'Шаран': 2,
#  'Переяславськ': 2,
#  'Яров': 2,
#  'Шмальцл': 2,
#  'Арас': 2,
#  'Вільярреал': 2,
#  'Кант': 2,
#  'Світлан (': 2,
#  'Юле': 2,
#  'Трач': 2,
#  'Мус Аб': 2,
#  'Палатн': 2,
#  'Шимк': 2,
#  'Аксельсен': 2,
#  'Гейл': 2,
#  'Патріс': 2,
#  'Арман': 2,
#  'Арор': 2,
#  'біолог': 2,
#  'Ко': 2,
#  'Вар': 2,
#  'Черниц': 2,
#  'Феофіл': 2,
#  'Зе': 2,
#  'Беспальк': 2,
#  'Фонд': 2,
#  'Дрю': 2,
#  'Чміліт': 2,
#  'Шал': 2,
#  'нотаріус': 2,
#  'Сіон': 2,
#  'Агат': 2,
#  'ендокринолог': 2,
#  'Пятидесятниц': 2,
#  'Конч': 2,
#  'Матковськ': 2,
#  'Доріс Де': 2,
#  'Вітал К': 2,
#  'Руд': 2,
#  'Джайлз': 2,
#  'Арід': 2,
#  'Андж': 2,
#  'Парван': 2,
#  'Лях': 2,
#  'Осак': 2,
#  'Ки': 2,
#  'Наїр': 2,
#  'Еркелін': 2,
#  'Гохлернер': 2,
#  'Мотт': 2,
#  'Дуарт': 2,
#  'Шах': 2,
#  'Фрід': 2,
#  'Берар': 2,
#  'Мер': 2,
#  'Йоел Аб': 2,
#  'Савельєв': 2,
#  'Санд': 2,
#  'Фехнер': 2,
#  'Віктор Де': 2,
#  'канцлер': 2,
#  'Стакіс': 2,
#  'Махмуд ал': 2,
#  'Гот': 2,
#  'Хаак': 2,
#  'футболист': 2,
#  'Шептицк': 2,
#  'Чжо': 2,
#  'Уил': 2,
#  'чет Гейтс': 2,
#  'ван Дейк': 2,
#  'Сис': 2,
#  'Ао': 2,
#  'Лусварг': 2,
#  'Лин': 2,
#  'П': 2,
#  'Смит': 2,
#  'Майкл С': 2,
#  'жительниц Алексеевк': 2,
#  'Кулиш': 2,
#  'Иса': 2,
#  'Анттон': 2,
#  'Роберт Ре': 2,
#  'Сайнароев': 2,
#  'одноклассниц Владислав': 2,
#  'Марлин': 2,
#  'ван Керхов': 2,
#  'Продукц': 2,
#  'Северинец': 2,
#  'Фріз': 2,
#  'Пєр': 2,
#  'Юнак': 2,
#  'Райт': 2,
#  'Кра': 2,
#  'Мейерс': 2,
#  'Емер': 2,
#  'Гірн': 2,
#  'Нер': 2,
#  'Страбон': 2,
#  'Омар': 2,
#  'Мінчук': 2,
#  'Штайнбрюк': 2,
#  'Бур': 2,
#  'Кур': 2,
#  'Хенсл': 2,
#  'Та': 2,
#  'Тиціан': 2,
#  'Наев': 2,
#  'Иван': 2,
#  'беремен': 2,
#  'Курц': 2,
#  'Чжу .': 2,
#  'Мура': 2,
#  'Кинс': 2,
#  'Левус': 2,
#  'Дон': 2,
#  'Всеволод': 2,
#  'Шеветовськ': 2,
#  'Сутченк': 2,
#  'Дольник': 2,
#  'Найштетік': 2,
#  'Чал': 2,
#  'Лер': 2,
#  'Устав': 2,
#  'Радонице': 2,
#  'Паш': 2,
#  'Авел': 2,
#  'Старік': 2,
#  'Соболевськ': 2,
#  'Феофіл Iiі': 2,
#  'Юльк': 2,
#  'Арін': 2,
#  'Лілі': 2,
#  'Як': 2,
#  'Ільчук': 2,
#  'Єгор': 2,
#  'протоієре Іоанн': 2,
#  'Пелюховськ': 2,
#  'Бож': 2,
#  'Гламаздін': 2,
#  'спецвипуск': 2,
#  'Кдаіс': 2,
#  'нікнейм': 2,
#  'Улюблениц Ям': 2,
#  'Прилєпін': 2,
#  'Ковальчук': 2,
#  'Шив': 2,
#  'Аніс': 2,
#  'Оле': 2,
#  'Теб': 2,
#  'Брав': 2,
#  'Льош': 2,
#  'Мік': 2,
#  'Мат': 2,
#  'Маг': 2,
#  'Шуран': 2,
#  'Ждан': 2,
#  '(': 2,
#  'Джайшанкар': 2,
#  'Руїс': 2,
#  'Карр': 2,
#  'Макмастер': 2,
#  'Племінниц': 2,
#  'Лі': 2,
#  'Генр': 2,
#  'Джерс': 2,
#  'Джо Шо': 2,
#  'Фердінанд': 2,
#  'Фарн': 2,
#  'Кутєп': 2,
#  'Мурад': 2,
#  'Телешецьк': 2,
#  'Бєлав': 2,
#  'коронавірус': 2,
#  'пятикласник': 2,
#  'Ельз': 2,
#  'Анжеліз': 2,
#  'Оп з антикризов комунікац': 2,
#  'Пінк': 2,
#  'Маф': 2,
#  'обл .': 2,
#  'Митропол': 2,
#  'Марез': 2,
#  'Саттур': 2,
#  'Тац': 2,
#  'Рябц': 2,
#  'и Лукашенк': 2,
#  'сержант': 2,
#  'Джейкоб Шо': 2,
#  'Алін К': 2,
#  'Жук': 2,
#  'Оуен': 2,
#  'Мавк': 2,
#  'тет': 2,
#  'т . в . о': 2,
#  'імунолог': 2,
#  'Ісс': 2,
#  'Шеліг': 2,
#  'Нгуен': 2,
#  'Дню': 2,
#  'Браж': 2,
#  'моряк': 2,
#  'Іке': 2,
#  'Ем': 2,
#  'Остапенк': 2,
#  'Люб': 2,
#  'Нік': 2,
#  'Алл': 2,
#  'Лукьяненк': 2,
#  'политолог': 2,
#  'Ан .': 2,
#  'Белашк': 2,
#  'Гродин': 2,
#  'Юр .': 2,
#  'статус Медведчук': 2,
#  'Александр Iii': 2,
#  'Миха Юл': 2,
#  'Туск': 2,
#  'Ел добав': 2,
#  'Гриш': 2,
#  'Елис .': 2,
#  'Флик': 2,
#  'Тон Ра': 2,
#  'иммунолог': 2,
#  'Ю': 2,
#  'Гол': 2,
#  'Физерстоун': 2,
#  'Лун': 2,
#  'Клюг': 2,
#  'Окса': 2,
#  'Будд': 2,
#  'Иззэддин аль-кассам': 2,
#  'Зубк': 2,
#  'Д': 2,
#  'Грэм': 2,
#  'Людм': 2,
#  'диетолог': 2,
#  'Ел .': 2,
#  'Анел': 2,
#  'Г': 2,
#  'режиссер': 2,
#  'эксперт': 2,
#  'рокер': 2,
#  'Мин': 2,
#  'Алекс К': 2,
#  'Жен': 2,
#  'Ввін': 2,
#  'Якал': 2,
#  'Лук': 2,
#  'Федін': 2,
#  'Аймон': 2,
#  'Булавін': 2,
#  'Фрііс': 2,
#  'Пірс': 2,
#  'Нью': 2,
#  'Чопр': 2,
#  'Дем': 2,
#  'Куевас': 2,
#  'Бугр': 2,
#  'адвокат Чаус': 2,
#  'Пьер .': 2,
#  'Дафф': 2,
#  'Круз': 2,
#  'Жада': 2,
#  'Стрелок': 2,
#  'Барм': 2,
#  'Фьюр': 2,
#  'Риффмастер': 2,
#  'Джин': 2,
#  'Метт': 2,
#  'Джа': 2,
#  'Приймак': 2,
#  'Апур': 2,
#  'журналист Есипенк': 2,
#  'Мтот': 1,
#  'Гульдер': 1,
#  'Бичихін': 1,
#  'Саєд': 1,
#  'Нікулін': 1,
#  'Гірмус': 1,
#  'Олігарх': 1,
#  'Драг': 1,
#  'Квон': 1,
#  'Ях': 1,
#  'Гом': 1,
#  'Георгіт': 1,
#  'Короненк': 1,
#  'Ю . Ю . зобовязан': 1,
#  'Кіпер': 1,
#  'Уеб': 1,
#  'Патол': 1,
#  'Накаям Ем': 1,
#  'у заяв Джейм': 1,
#  'Кілмен': 1,
#  'Рогатнев': 1,
#  'Провіденс': 1,
#  'Діян': 1,
#  'Dj Мадонн': 1,
#  'Гліб': 1,
#  'Гуморист': 1,
#  'Міхельсон': 1,
#  'Ір': 1,
#  'Садіх': 1,
#  'Карпинськ': 1,
#  'Фом': 1,
#  'Материнськ': 1,
#  'Богдан розсекретил': 1,
#  'сім Ве Ве': 1,
#  'Віл Лі': 1,
#  'Егілс': 1,
#  'Кондитер': 1,
#  'Холмарк': 1,
#  'Мартін Ян': 1,
#  'Зелмер': 1,
#  'Миколайович Tuttomercatoweв': 1,
#  'Дел': 1,
#  'Бузин': 1,
#  'Велонек': 1,
#  'Монсон': 1,
#  'власник " Шахтар "': 1,
#  'Бошир': 1,
#  'Джош знущальн': 1,
#  'Імпарат': 1,
#  'Туллекен': 1,
#  'Тел Ал': 1,
#  'Хассанат': 1,
#  'Рімал': 1,
#  'Ліберман': 1,
#  'Ейдан Шо': 1,
#  'Сіян': 1,
#  'Інн П': 1,
#  'Славінськ': 1,
#  'Ришк': 1,
#  'Мовознавец': 1,
#  'Фірс': 1,
#  'Дів': 1,
#  'Михайл Яц': 1,
#  'Офіс Президент ( Оп': 1,
#  'Кетрін Лі': 1,
#  'модельєрк Молл': 1,
#  'Кривицьк': 1,
#  'Григулецьк': 1,
#  'Нємц': 1,
#  'Решк': 1,
#  'Ентон "': 1,
#  'Тяг': 1,
#  'Сабрін': 1,
#  'Орлуш': 1,
#  'Джоболд': 1,
#  'Макалір': 1,
#  'Матеуш': 1,
#  'Ашурак': 1,
#  'Кошелек': 1,
#  'Недр': 1,
#  'Філіп "': 1,
#  'Нуссенцвейг': 1,
#  'Килюшик': 1,
#  'Тіс "': 1,
#  'Герасимчук': 1,
#  'Луїс': 1,
#  'Май': 1,
#  'Макеєв': 1,
#  'Іллінц': 1,
#  'Санч': 1,
#  'Блюм': 1,
#  'Хіш ал': 1,
#  'Хельм': 1,
#  'Седрік О': 1,
#  'Лаутербах': 1,
#  'Ольбурз': 1,
#  'Жот': 1,
#  'Вн': 1,
#  'Рендалл': 1,
#  'Райс': 1,
#  'Нвв': 1,
#  'Джем "': 1,
#  'Візір': 1,
#  'Барбус': 1,
#  'Фсб': 1,
#  'Чайлд': 1,
#  'Джул': 1,
#  'Николаевгаз': 1,
#  'Мнздрав': 1,
#  'Кашмір': 1,
#  'Тордис': 1,
#  'Реттген': 1,
#  'Типтр': 1,
#  'Таб': 1,
#  'Портал Axios': 1,
#  'Губопік': 1,
#  '90-летн Баффет': 1,
#  'Бонд': 1,
#  'Симоніт': 1,
#  'Укрспецэкспорт': 1,
#  'Сенцов': 1,
#  'Афанасьев': 1,
#  'Перссон': 1,
#  'Керх': 1,
#  'Владимир снов': 1,
#  'Витал К .': 1,
#  'Тхорик': 1,
#  'Мурниец': 1,
#  'Лаг ба-омер': 1,
#  'Рахим': 1,
#  'Магав': 1,
#  'Левитс': 1,
#  'Денис Live': 1,
#  'Мам': 1,
#  'Эдвардс': 1,
#  'Нефьодов': 1,
#  'Ai': 1,
#  'Элефтер': 1,
#  'Волынец': 1,
#  'Тапанов': 1,
#  'Шелевицьк': 1,
#  'шериф': 1,
#  'Диллер': 1,
#  'Лорт': 1,
#  'Выговск': 1,
#  'Антипутін': 1,
#  'Мі': 1,
#  'Прядк': 1,
#  'Пантелєєв': 1,
#  'Зільберман': 1,
#  'Кацман': 1,
#  'Боомолец': 1,
#  'Галенк': 1,
#  'Данн': 1,
#  'Епкогг': 1,
#  'Овчинник': 1,
#  'в " Шахтар "': 1,
#  'Джус': 1,
#  'Луцевич': 1,
#  'Азар': 1,
#  'Горач': 1,
#  'Никандр': 1,
#  'Жвл': 1,
#  'християнин': 1,
#  'семикласник': 1,
#  'Лісіцин': 1,
#  'Тайг . инф': 1,
#  'Мах': 1,
#  'Пятидесятнице': 1,
#  'Швец': 1,
#  'ван Дрил': 1,
#  'Тільс': 1,
#  'Бісмарк': 1,
#  'Росін': 1,
#  'стиліст': 1,
#  'Каргб': 1,
#  'Писанк': 1,
#  'Тек Ік': 1,
#  'Настояще врем': 1,
#  'Схем': 1,
#  'Карac': 1,
#  'Сеп': 1,
#  'Канх Ся': 1,
#  'Кіллінджер': 1,
#  'Порошенк – ред . )': 1,
#  'Тюрпел': 1,
#  'Лафонд': 1,
#  'Стерліг': 1,
#  'Гасумян': 1,
#  'Фі': 1,
#  'Арундел': 1,
#  'Волощук': 1,
#  'Гіндос': 1,
#  'Хампден': 1,
#  'Ск': 1,
#  'Звіт': 1,
#  'Глагол': 1,
#  'Ватр': 1,
#  'Тридуб': 1,
#  'Дітр': 1,
#  'Елізонд': 1,
#  'Румер': 1,
#  'Мішел в Twitter': 1,
#  'Сок': 1,
#  'Колиняк': 1,
#  'Борщевськ': 1,
#  'Клод': 1,
#  'Бірол': 1,
#  'Сутар': 1,
#  'Пр': 1,
#  'Органіц': 1,
#  'Сьямм': 1,
#  'Ерік': 1,
#  'Держав': 1,
#  'Інфантін': 1,
#  'Сітін': 1,
#  'Темблорес': 1,
#  'Сорд': 1,
#  'Бас': 1,
#  'Маям': 1,
#  'Холечек': 1,
#  'Еллісон': 1,
#  'Ашурок': 1,
#  'Андре Гі': 1,
#  'містер Блінкен': 1,
#  'Щепаньськ': 1,
#  'Мцхет': 1,
#  'Пекер': 1,
#  'Гре': 1,
#  'Перлман': 1,
#  'Матроскін': 1,
#  'Кіт': 1,
#  'Закарпатец': 1,
#  'Гуджар': 1,
#  'Ляньх': 1,
#  'Од': 1,
#  'Уаїл Іс': 1,
#  'Пьянов': 1,
#  'Вітал Юг': 1,
#  'Світл пятниц': 1,
#  '63-річн Еллен': 1,
#  'Ваєт': 1,
#  'Марф': 1,
#  'Ремз': 1,
#  'Гайченк': 1,
#  'Антипасх': 1,
#  'Тафт': 1,
#  'Джентльмен Га': 1,
#  'Еммченк': 1,
#  'Ставнич': 1,
#  'Фозз': 1,
#  'Ставіч': 1,
#  'Гієн': 1,
#  'Барр': 1,
#  'Бардаш': 1,
#  'Дієт': 1,
#  'Муадд': 1,
#  'Юр М': 1,
#  'Кривоше': 1,
#  'Сміюх': 1,
#  'Асі': 1,
#  ...}

# %%
### adding missing names to names dict

# missing_names = [name for name if missing_counts.keys() if re.search(r'[А-ЯЇҐЄІ]\S* [А-ЯЇҐЄІ]\S*', name)]
# for name in missing_names:
#     names_df.loc[name, 'num'] = missing_counts[name]
#     names_df.loc[name, 'id'] = names_df.id.max()+1
# names_df.to_csv(names_dict_path)

# %%
entities['names_found'] = entities.names_from_dict.apply(lambda d:
                                                 list(dict(sorted(d.items())).values()) if pd.notna(d) else None)

# %%
entities['found_names_str'] = entities.names_found.apply(lambda names: 
                                                    '§'.join(names) if isinstance(names, list) else None)

# %%
entities.found_names_str.notna().sum()
# Out:
# 71557

# %%
entities.columns
# Out:
# Index(['link', 'language', 'all_ent_str', 'name_and_kw', 'kw_and_ent',
#        'names_and_kw_str', 'names_str', 'names_sets_str',
#        'one_name_per_set_str', 'string_names_sets_str', 'filt_kw_names_str',
#        'checked_with_conllu', 'checked_names_str', 'kw_names_unique_str',
#        'unique_kw_names', 'names_from_dict', 'found', 'names_found',
#        'found_names_str', 'dict_str'],
#       dtype='object')

# %%
entities[['link', 'language', 'all_ent_str', 'name_and_kw', 'kw_and_ent',
       'names_and_kw_str', 'names_str', 'names_sets_str',
       'one_name_per_set_str', 'string_names_sets_str', 'filt_kw_names_str',
       'checked_with_conllu', 'checked_names_str', 'kw_names_unique_str',
       'found', 'found_names_str', 'dict_str']].to_csv(entities_path)

# %%
news_filepath = '../data/may.csv'
news = pd.read_csv(news_filepath, index_col=[0])
news.columns
# Out:
# Index(['title', 'text', 'subtitle', 'link', 'domain', 'datetime', 'views',
#        'created_at', 'category', 'language', 'domain_alias', 'mycategory'],
#       dtype='object')

# %%
news['found_names_str'] = entities['found_names_str']

# %%
news.to_csv(news_filepath)

# %%
def dict_to_str(names_from_dict):
    if pd.notna(names_from_dict):
        res = []
        for k, v in names_from_dict.items():
            res.append('§'.join([str(k), v]))
        return '<+>'.join(res)
    return None

# %%
entities[entities.names_from_dict.notna()].shape
# Out:
# (71557, 19)

# %%
entities['dict_str'] = entities.names_from_dict.apply(dict_to_str)
